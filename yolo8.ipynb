# %%
import torch 
from IPython.display import Image

# %%
# %cd yoloV8
# Out:
# D:\ProyectoBotellas\yoloV8

# %%
print('All set. Using PyTorch version %s with %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# All set. Using PyTorch version 2.0.1+cu117 with _CudaDeviceProperties(name='NVIDIA GeForce RTX 3050 Laptop GPU', major=8, minor=6, total_memory=4095MB, multi_processor_count=16)

# %%
# !python main.py --img 416 --batch 16 --epochs 50 --data dataset.yaml --weights yolov8n.pt --cache
# Out:
# 0: 480x640 1 A, 614.4ms
# Speed: 155.8ms preprocess, 614.4ms inference, 157.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 As, 40.5ms
# Speed: 0.0ms preprocess, 40.5ms inference, 10.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 As, 36.8ms
# Speed: 0.0ms preprocess, 36.8ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 As, 41.1ms
# Speed: 0.0ms preprocess, 41.1ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 As, 37.2ms
# Speed: 3.0ms preprocess, 37.2ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 As, 41.0ms
# Speed: 2.7ms preprocess, 41.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 As, 37.6ms
# Speed: 1.5ms preprocess, 37.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 As, 31.9ms
# ...
